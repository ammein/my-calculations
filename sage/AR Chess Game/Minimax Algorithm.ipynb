# %%
# A simple Python3 program to find
# maximum score that
# maximizing player can get
import math
from sage.graphs.digraph import DiGraph
from sage.rings.integer import Integer

from sage import *

D = DiGraph()

val = {}

def minimax(curDepth, nodeIndex,
            maxTurn, scores,
            targetDepth):
    # base case : targetDepth reached
    if (curDepth == targetDepth):
        D.add_edge((nodeIndex, curDepth), scores[nodeIndex])
        return scores[nodeIndex]

    if (maxTurn):
        return max(minimax(curDepth + 1, nodeIndex * 2,
                           False, scores, targetDepth),
                   minimax(curDepth + 1, nodeIndex * 2 + 1,
                           False, scores, targetDepth))

    else:
        return min(minimax(curDepth + 1, nodeIndex * 2,
                           True, scores, targetDepth),
                   minimax(curDepth + 1, nodeIndex * 2 + 1,
                           True, scores, targetDepth))


# Driver code
scores = [3, 5, 2, 9, 12, 5, 23, 23]

treeDepth = math.log(len(scores), 2)
print(treeDepth)

print("The optimal value is : ", end="")
# print(minimax(0, 0, True, scores, treeDepth))
minimax(0, 0, True, scores, treeDepth)
D.graphplot(vertex_size=2000.,  layout="tree", tree_root=Integer(0)).show()

# This code is contributed
# by rootshadow
# Out:
# 3.0
# The optimal value is :
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/8s/x1wy2xz14_b9rc9pbyh2xn1w0000gn/T/ipykernel_5218/629553999.py in ?()
#      40
#      41 print("The optimal value is : ", end="")
#      42 # print(minimax(0, 0, True, scores, treeDepth))
#      43 minimax(Integer(0), Integer(0), True, scores, treeDepth)
# ---> 44 D.graphplot(vertex_size=RealNumber('2000.'),  layout="tree", tree_root=Integer(Integer(0))).show()
#      45
#      46 # This code is contributed
#      47 # by rootshadow
#
# /opt/anaconda3/envs/my-calculations/lib/python3.12/site-packages/sage/graphs/generic_graph.py in ?(self, **options)
#   21888             sage: GP.plot()
#   21889             Graphics object consisting of 22 graphics primitives
#   21890         """
#   21891         from sage.graphs.graph_plot import GraphPlot
# > 21892         return GraphPlot(graph=self, options=options)
#
# /opt/anaconda3/envs/my-calculations/lib/python3.12/site-packages/sage/graphs/graph_plot.py in ?(self, graph, options)
#     323         self._arcs = self._graph.has_multiple_edges(to_undirected=True)
#     324         self._loops = self._graph.has_loops()
#     325         self._arcdigraph = self._graph.is_directed() and self._arcs
#     326
# --> 327         self.set_pos()
#     328         self.set_vertices()
#     329         self.set_edges()
#
# /opt/anaconda3/envs/my-calculations/lib/python3.12/site-packages/sage/graphs/graph_plot.py in ?(self)
#     400
#     401             sage: Graph({u'où': [u'là', u'ici']}).plot()
#     402             Graphics object consisting of 6 graphics primitives
#     403         """
# --> 404         self._pos = self._graph.layout(**self._options)
#     405         # Make sure the positions are floats (trac #10124)
#     406         self._pos = {k: (float(v[0]), float(v[1]))
#     407                      for k, v in self._pos.items()}
#
# /opt/anaconda3/envs/my-calculations/lib/python3.12/site-packages/sage/graphs/generic_graph.py in ?(self, layout, pos, dim, save_pos, **options)
#   21056             if pos is None:
#   21057                 layout = 'default'
#   21058
#   21059         if hasattr(self, "layout_%s" % layout):
# > 21060             pos = getattr(self, "layout_%s" % layout)(dim=dim, **options)
#   21061         elif layout is not None:
#   21062             raise ValueError("unknown layout algorithm: %s" % layout)
#   21063
#
# /opt/anaconda3/envs/my-calculations/lib/python3.12/site-packages/sage/graphs/generic_graph.py in ?(self, tree_orientation, tree_root, dim, **options)
#   21437             return dict()
#   21438
#   21439         from sage.graphs.graph import Graph
#   21440         if not Graph(self).is_tree():
# > 21441             raise RuntimeError("cannot use tree layout on this graph: "
#   21442                                "self.is_tree() returns False")
#   21443
#   21444         emb = self.get_embedding()
#
# RuntimeError: cannot use tree layout on this graph: self.is_tree() returns False
